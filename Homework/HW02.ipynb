# %%
import glob
import pandas as pd

# %%
path = r'C:\Data\PyData\AirQty(201604)'
fnames = glob.glob(path + r'\**\*.csv', recursive=True)
pd.concat([pd.read_csv(file, sep=',', encoding='cp950', engine='python') for file in fnames], axis=0, \
          verify_integrity=True, ignore_index=True)
# Out:
#      SiteName County  PSI MajorPollutant Status  SO2    CO    O3   PM10  \
# 0          麥寮    雲林縣   70           懸浮微粒     普通  2.9  0.42  66.0   83.0
# 1          關山    臺東縣   36            NaN     良好  1.0   NaN  30.0   46.0
# 2          馬公    澎湖縣   54             臭氧     普通  2.4  0.46  64.0   63.0
# 3          金門    金門縣   59           懸浮微粒     普通  2.2  0.47  54.0   76.0
# 4          馬祖    連江縣   55             臭氧     普通  1.4  0.39  67.0   60.0
# ...       ...    ...  ...            ...    ...  ...   ...   ...    ...
# 2275       土城    新北市   80           懸浮微粒     普通  2.5  0.60  76.0  101.0
# 2276       新店    新北市   77           懸浮微粒     普通  2.7  0.58  77.0   96.0
# 2277       萬里    新北市   70           懸浮微粒     普通  3.7  0.47  56.0   72.0
# 2278       汐止    新北市   78           懸浮微粒     普通  2.6  0.65  63.0   97.0
# 2279       基隆    基隆市   68             臭氧     普通  2.2  0.54  81.0   64.0
#
#       PM2.5   NO2  WindSpeed  WindDirec  FPMI    NOx    NO      PublishTime
# 0      47.0   8.4        2.0       31.0   6.0   9.92  1.48   2016/4/1 20:00
# 1      22.0   9.7        1.1       62.0   2.0  10.83  1.15   2016/4/1 20:00
# 2      44.0   7.2        1.2      326.0   4.0   9.00  1.78   2016/4/1 20:00
# 3      45.0  17.0        1.3       34.0   5.0  17.42  0.68   2016/4/1 20:00
# 4      48.0   9.4        1.8       31.0   5.0  10.12  0.76   2016/4/1 20:00
# ...     ...   ...        ...        ...   ...    ...   ...              ...
# 2275   49.0  12.0        2.4      261.0   6.0  12.79  0.71  2016/4/30 02:00
# 2276   54.0  12.0        2.8       73.0   8.0  12.90  0.84  2016/4/30 02:00
# 2277   47.0   4.8        3.9      218.0   7.0   5.24  0.48  2016/4/30 02:00
# 2278   62.0  18.0        1.0       70.0   8.0  19.69  1.32  2016/4/30 02:00
# 2279   35.0   8.6        2.1       74.0   6.0   9.51  0.96  2016/4/30 02:00
#
# [2280 rows x 17 columns]
